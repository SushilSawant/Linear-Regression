# %% [markdown]
# ## Prediction model for profit of 50_startups

# %%
# import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
import statsmodels.api as sm
from statsmodels.graphics.regressionplots import influence_plot

# %%
# import dataset
data=pd.read_csv("downloads/50_Startups.csv")
data.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
data[data.duplicated()] # No duplicated data
# Out:
# Empty DataFrame
# Columns: [R&D Spend, Administration, Marketing Spend, State, Profit]
# Index: []

# %%
data.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
data_1=data.rename({'R&D Spend':'RDS','Administration':'ADMS','Marketing Spend':'MKTS'},axis=1)
data_1.head()
# Out:
#          RDS       ADMS       MKTS       State     Profit
# 0  165349.20  136897.80  471784.10    New York  192261.83
# 1  162597.70  151377.59  443898.53  California  191792.06
# 2  153441.51  101145.55  407934.54     Florida  191050.39
# 3  144372.41  118671.85  383199.62    New York  182901.99
# 4  142107.34   91391.77  366168.42     Florida  166187.94

# %%
data_1.corr()
# Out:
#              RDS      ADMS      MKTS    Profit
# RDS     1.000000  0.241955  0.724248  0.972900
# ADMS    0.241955  1.000000 -0.032154  0.200717
# MKTS    0.724248 -0.032154  1.000000  0.747766
# Profit  0.972900  0.200717  0.747766  1.000000

# %%
sns.set()

# %%
sns.heatmap(data_1.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(data_1)#sns.set_style(style='darkgrid')

# %%
model=smf.ols("Profit~RDS+ADMS+MKTS",data=data_1).fit()

# %%
# Finding Coefficient parameters
model.params
# Out:
# Intercept    50122.192990
# RDS              0.805715
# ADMS            -0.026816
# MKTS             0.027228
# dtype: float64

# %%
# Finding tvalues and pvalues
model.tvalues , np.round(model.pvalues,5)
# Out:
# (Intercept     7.626218
#  RDS          17.846374
#  ADMS         -0.525507
#  MKTS          1.655077
#  dtype: float64,
#  Intercept    0.00000
#  RDS          0.00000
#  ADMS         0.60176
#  MKTS         0.10472
#  dtype: float64)

# %%
# Finding rsquared values
model.rsquared , model.rsquared_adj
# Out:
# (0.9507459940683246, 0.9475337762901719)

# %%
# The ADMS and MKTS both variables are having the same behaviour so we select select one variable
# Build SLR and MLR models for insignificant variables 'ADMS' and 'MKTS'
# Also find their tvalues and pvalues

# %%
slr_a=smf.ols("Profit~ADMS",data=data_1).fit()
slr_a.tvalues , slr_a.pvalues  # ADMS has in-significant pvalue
# Out:
# (Intercept    3.040044
#  ADMS         1.419493
#  dtype: float64,
#  Intercept    0.003824
#  ADMS         0.162217
#  dtype: float64)

# %%
slr_m=smf.ols("Profit~MKTS",data=data_1).fit()
slr_m.tvalues , slr_m.pvalues  # MKTS has significant pvalue
# Out:
# (Intercept    7.808356
#  MKTS         7.802657
#  dtype: float64,
#  Intercept    4.294735e-10
#  MKTS         4.381073e-10
#  dtype: float64)

# %%
mlr_am=smf.ols("Profit~ADMS+MKTS",data=data_1).fit()
mlr_am.tvalues , mlr_am.pvalues  # varaibles have significant pvalues
# Out:
# (Intercept    1.142741
#  ADMS         2.467779
#  MKTS         8.281039
#  dtype: float64,
#  Intercept    2.589341e-01
#  ADMS         1.729198e-02
#  MKTS         9.727245e-11
#  dtype: float64)

# %% [markdown]
# ## Model Validation
# ## Two Techniques: 1. Collinearity Check & 2. Residual Analysis

# %%
# 1) Collinearity Problem Check
# Calculate VIF = 1/(1-Rsquare) for all independent variables

rsq_RDS=smf.ols("RDS~ADMS+MKTS",data=data_1).fit().rsquared
vif_RDS=1/(1-rsq_RDS)

rsq_ADMS=smf.ols("ADMS~RDS+MKTS",data=data_1).fit().rsquared
vif_ADMS=1/(1-rsq_ADMS)

rsq_MKTS=smf.ols("MKTS~RDS+ADMS",data=data_1).fit().rsquared
vif_MKTS=1/(1-rsq_MKTS)

# Putting the values in Dataframe format
d1={'Variables':['RDS','ADMS','MKTS'],'Vif':[vif_RDS,vif_ADMS,vif_MKTS]}
Vif_df=pd.DataFrame(d1)
Vif_df
# Out:
#   Variables       Vif
# 0       RDS  2.468903
# 1      ADMS  1.175091
# 2      MKTS  2.326773

# %%
# No variable has VIF>20, No Collinearity, so consider all varaibles in Regression equation

# %% [markdown]
# ## 2) Residual Analysis

# %%
# Test for Normality of Residuals (Q-Q Plot) using residual model (model.resid)

sm.qqplot(model.resid,line='q')
plt.title("Normal Q-Q plot of residuals")
plt.show()

# %%
list(np.where(model.resid<-30000))
# Out:
# [array([49], dtype=int64)]

# %%
# Test for Homoscedasticity or Heteroscedasticity (plotting model's standardized fitted values vs standardized residual values)

def standard_values(vals) : return (vals-vals.mean())/vals.std()  # User defined z = (x - u)/sigma

# %%
plt.scatter(standard_values(model.fittedvalues),standard_values(model.resid))
plt.title('Residual Plot')
plt.xlabel('standardized fitted values')
plt.ylabel('standardized residual values')
plt.show()

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'RDS',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'ADMS',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'MKTS',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %% [markdown]
# ## Model Deletion Diagnostics (checking Outliers or Influencers)
# ## Two Techniques : 1. Cook's Distance & 2. Leverage value
#  1. Cook's Distance: If Cook's distance > 1, then it's an outlier
#  Get influencers using cook's distance

# %%
(c,_)=model.get_influence().cooks_distance
c
# Out:
# array([3.21825244e-05, 3.27591036e-03, 3.23842699e-02, 2.17206555e-02,
#        1.44833032e-02, 1.17158463e-02, 2.91766303e-03, 3.56513444e-03,
#        4.04303948e-05, 4.86758017e-03, 1.51064757e-02, 1.63564959e-02,
#        1.15516625e-02, 4.01422811e-03, 6.12934253e-02, 3.40013448e-02,
#        8.33556413e-03, 3.30534399e-03, 2.16819303e-03, 4.07440577e-02,
#        4.25137222e-04, 1.09844352e-02, 2.91768000e-03, 2.76030254e-04,
#        5.04643588e-03, 3.00074623e-03, 3.41957068e-03, 2.98396413e-02,
#        1.31590664e-03, 1.25992620e-04, 4.18505125e-05, 9.27434786e-06,
#        7.08656521e-04, 1.28122674e-04, 2.09815032e-02, 6.69508674e-03,
#        5.55314705e-02, 6.55050578e-05, 5.61547311e-02, 1.54279607e-03,
#        1.84850929e-03, 1.97578066e-03, 1.36089280e-04, 2.05553171e-02,
#        1.23156041e-04, 9.03234206e-02, 5.45303387e-02, 5.33885616e-03,
#        1.90527441e-01, 2.88082293e-01])

# %%
# Plot the influencers using the stem plot
fig=plt.figure(figsize=(20,7))
plt.stem(np.arange(len(data_1)),np.round(c,5))
plt.xlabel('Row Index')
plt.ylabel('Cooks Distance')
plt.show()

# %%
# Index and value of influencer where C>0.5
np.argmax(c) , np.max(c)
# Out:
# (49, 0.28808229275432673)

# %% [markdown]
# ### 2. Leverage Value using High Influence Points : Points beyond Leverage_cutoff value are influencers

# %%
influence_plot(model)
plt.show()

# %% [markdown]
# # Leverage Cuttoff Value = 3*(k+1)/n ; k = no.of features/columns & n = no. of datapoints

# %%
k=data_1.shape[1]
n=data_1.shape[0]
leverage_cutoff = (3*(k+1))/n
leverage_cutoff
# Out:
# 0.36

# %%
data_1[data_1.index.isin([49])]
# Out:
#     RDS      ADMS      MKTS       State   Profit
# 49  0.0  116983.8  45173.06  California  14681.4

# %% [markdown]
# ## Improving the Model

# %%
# Discard the data points which are influencers and reassign the row number (reset_index(drop=True))
data_2=data_1.drop(data_1.index[[49]],axis=0).reset_index(drop=True)
data_2.head()
# Out:
#          RDS       ADMS       MKTS       State     Profit
# 0  165349.20  136897.80  471784.10    New York  192261.83
# 1  162597.70  151377.59  443898.53  California  191792.06
# 2  153441.51  101145.55  407934.54     Florida  191050.39
# 3  144372.41  118671.85  383199.62    New York  182901.99
# 4  142107.34   91391.77  366168.42     Florida  166187.94

# %% [markdown]
# ## Model Deletion Diagnostics and Final Model

# %%
while np.max(c)>0.5 :
    model=smf.ols("Profit~RDS+ADMS+MKTS",data=data_2).fit()
    (c,_)=model.get_influence().cooks_distance
    c
    np.argmax(c) , np.max(c)
    data_2=data2.drop(data_2.index[[np.argmax(c)]],axis=0).reset_index(drop=True)
    data_2
else:
    final_model=smf.ols("Profit~RDS+ADMS+MKTS",data=data_2).fit()
    final_model.rsquared , final_model.aic
    print("The model accuracy is improved to",final_model.rsquared)
# Out:
# The model accuracy is improved to 0.9613162435129847

# %%
  final_model.rsquared , final_model.aic
# Out:
# (0.9613162435129847, 1020.5652974526367)

# %%
data_2.head()
# Out:
#          RDS       ADMS       MKTS       State     Profit
# 0  165349.20  136897.80  471784.10    New York  192261.83
# 1  162597.70  151377.59  443898.53  California  191792.06
# 2  153441.51  101145.55  407934.54     Florida  191050.39
# 3  144372.41  118671.85  383199.62    New York  182901.99
# 4  142107.34   91391.77  366168.42     Florida  166187.94

# %% [markdown]
# ## Prediction for new data

# %%
# say New data for prediction is
new_data=pd.DataFrame({'RDS':70000,"ADMS":90000,"MKTS":140000},index=[0])
new_data
# Out:
#      RDS   ADMS    MKTS
# 0  70000  90000  140000

# %%
# Manual Prediction of Price
final_model.predict(new_data)
# Out:
# 0    108727.154753
# dtype: float64

# %%
# Automatic Prediction of Price with 90.02% accurcy
pred_y=final_model.predict(data_2.iloc[:,:-1])
pred_y.head()
# Out:
# 0    190716.676999
# 1    187537.122227
# 2    180575.526396
# 3    172461.144642
# 4    170863.486721
# dtype: float64

# %% [markdown]
# # R Squared values compariosion of model and final model

# %%
R_Values={'Prep_Models':['Model','Final_Model'],'Rsquared':[model.rsquared*100,final_model.rsquared*100]}
table=pd.DataFrame(R_Values)
table
# Out:
#    Prep_Models   Rsquared
# 0        Model  95.074599
# 1  Final_Model  96.131624
